# %%
import numpy as np

# %%
print("hello")
# Out:
# hello

# %%
1+1
# Out:
# 2

# %%
numbers = [1,2,3]
print(numbers)
# Out:
# [1, 2, 3]

# %%
doubled = numbers * 2
print(doubled)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
arr = np.array([1,2,3])
arr_doubled = arr * 2
print(arr_doubled)
# Out:
# [2 4 6]

# %%
my_list = [3,6,9,12]
my_arr = np.array(my_list)
print(my_list)
print(my_arr)
# Out:
# [3, 6, 9, 12]
# [ 3  6  9 12]

# %%
data = [44,8,32,45,37,42,47,26,31,11]
print(np.mean(data))
print(np.median(data))
print(np.std(data))
print(np.var(data))
# Out:
# 32.3
# 34.5
# 13.1
# 171.61

# %%
nested = [
    [1,2,3],
    [4,5,6]
]
print(nested[0][0])
# Out:
# 1

# %%
ndarray = np.array([
    [1,2,3],[4,5,6]])
print(ndarray[:,1])
# Out:
# [2 5]
